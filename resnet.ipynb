# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Rescaling, Activation, Dropout, Flatten, Dense, GlobalMaxPooling2D, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import ResNet50

import os
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
train_dir = r'.C:\Users\sruja\archive\ODIR-5K\ODIR-5K\Testing Images'
test_dir = r'.C:\Users\sruja\archive\ODIR-5K\ODIR-5K\Training Images'

BATCH_SIZE = 32
IMG_HEIGHT = 264
IMG_WIDTH = 264
EPOCHS = 100

input_shape = (IMG_WIDTH, IMG_HEIGHT, 3)

# %%
training_generator = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    shuffle=True,
    seed=432,
    validation_split=0.2,
    subset='training',
)

validation_generator = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    shuffle=True,
    seed=432,
    validation_split=0.2,
    subset='validation',
)

test_generator = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='categorical',
    shuffle=False,
    batch_size=BATCH_SIZE,
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    seed=432,
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 training_generator = tf.keras.utils.image_dataset_from_directory(
#       2     train_dir,
#       3     labels='inferred',
#       4     label_mode='categorical',
#       5     batch_size=BATCH_SIZE,
#       6     image_size=(IMG_WIDTH, IMG_HEIGHT),
#       7     shuffle=True,
#       8     seed=432,
#       9     validation_split=0.2,
#      10     subset='training',
#      11 )
#      13 validation_generator = tf.keras.utils.image_dataset_from_directory(
#      14     train_dir,
#      15     labels='inferred',
#    (...)
#      22     subset='validation',
#      23 )
#      25 test_generator = tf.keras.utils.image_dataset_from_directory(
#      26     test_dir,
#      27     labels='inferred',
#    (...)
#      32     seed=432,
#      33 )
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_dataset_utils.py:223, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     221 if seed is None:
#     222     seed = np.random.randint(1e6)
# --> 223 image_paths, labels, class_names = dataset_utils.index_directory(
#     224     directory,
#     225     labels,
#     226     formats=ALLOWLIST_FORMATS,
#     227     class_names=class_names,
#     228     shuffle=shuffle,
#     229     seed=seed,
#     230     follow_links=follow_links,
#     231     verbose=verbose,
#     232 )
#     234 if label_mode == "binary" and len(class_names) != 2:
#     235     raise ValueError(
#     236         'When passing `label_mode="binary"`, there must be exactly 2 '
#     237         f"class_names. Received: class_names={class_names}"
#     238     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\dataset_utils.py:537, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     535 if labels == "inferred":
#     536     subdirs = []
# --> 537     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     538         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     539             if not subdir.startswith("."):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\lib\io\file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)
#     765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory .C:\Users\sruja\archive\ODIR-5K\ODIR-5K\Testing Images
